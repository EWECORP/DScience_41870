# %% [markdown]
# ![CODERHOUSE.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # **CURSO DE DATA SCIENCE**
#
# # **DATA ACQUISITION**
#
# # **DESAFIO N° 7 - DESCARGA DE DATOS DE APIs PUBLICAS**
#
# *AUTOR:Leonardo CLARO*

# %% [markdown]
# # <b> Conectamos el Drive

# %%
from google.colab import drive
import os
drive.mount('/content/gdrive')
# Establecer ruta de acceso en drive
import os
print(os.getcwd())
os.chdir("/content/gdrive/My Drive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# /content/gdrive/My Drive/Colab Notebooks/DataScience/7ma entrega

# %% [markdown]
# # <b> Definimos carpeta de trabajo

# %%
# %cd '/content/gdrive/MyDrive/Colab Notebooks/DataScience/7ma entrega'
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/DataScience/7ma entrega

# %% [markdown]
# # JSON

# %%
import json
file_json=open('Provincias_Argentinas.json')
data=json.load(file_json)
data
# Out:
# {'Nombre Completo': {'0': 'Provincia de Misiones',
#   '1': 'Provincia de San Luis',
#   '2': 'Provincia de San Juan',
#   '3': 'Provincia de Entre Ríos',
#   '4': 'Provincia de Santa Cruz',
#   '5': 'Provincia de Río Negro',
#   '6': 'Provincia del Chubut',
#   '7': 'Provincia de Córdoba',
#   '8': 'Provincia de Mendoza',
#   '9': 'Provincia de La Rioja',
#   '10': 'Provincia de Catamarca',
#   '11': 'Provincia de La Pampa',
#   '12': 'Provincia de Santiago del Estero',
#   '13': 'Provincia de Corrientes',
#   '14': 'Provincia de Santa Fe',
#   '15': 'Provincia de Tucumán',
#   '16': 'Provincia del Neuquén',
#   '17': 'Provincia de Salta',
#   '18': 'Provincia del Chaco',
#   '19': 'Provincia de Formosa',
#   '20': 'Provincia de Jujuy',
#   '21': 'Ciudad Autónoma de Buenos Aires',
#   '22': 'Provincia de Buenos Aires',
#   '23': 'Provincia de Tierra del Fuego,  Antártida e Islas del Atlántico Sur'},
#  'Fuente': {'0': 'IGN',
#   '1': 'IGN',
#   '2': 'IGN',
#   '3': 'IGN',
# ...

# %%
x='''{
  "Nombre": "Leonardo Oscar Martín Claro",
  "Número de Contacto": 156226640,  
  "Email":"claro.leonardo.oscar@gmail.com",
  "Hobbies": ["Taekwondo","Futbol","Inteligencia Artificial","Inteligencia de Negocio","Mecánica de Motos"]
}
'''
y= json.loads(x)
y
# Out:
# {'Nombre': 'Leonardo Oscar Martín Claro',
#  'Número de Contacto': 156226640,
#  'Email': 'claro.leonardo.oscar@gmail.com',
#  'Hobbies': ['Taekwondo',
#   'Futbol',
#   'Inteligencia Artificial',
#   'Inteligencia de Negocio',
#   'Mecánica de Motos']}

# %%
import pandas as pd
a=pd.read_json('Provincias_Argentinas.json',orient='column')
print(type(a))
a.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#            Nombre Completo Fuente Iso_ID      Nombre  Id  Categoría  \
# 0    Provincia de Misiones    IGN   AR-N    Misiones  54  Provincia
# 1    Provincia de San Luis    IGN   AR-D    San Luis  74  Provincia
# 2    Provincia de San Juan    IGN   AR-J    San Juan  70  Provincia
# 3  Provincia de Entre Ríos    IGN   AR-E  Entre Ríos  30  Provincia
# 4  Provincia de Santa Cruz    IGN   AR-Z  Santa Cruz  78  Provincia
#
#    Iso_Nombre    Latitud   Longitud
# 0    Misiones -26.875397 -54.651697
# 1    San Luis -33.757726 -66.028130
# 2    San Juan -30.865368 -68.889491
# 3  Entre Ríos -32.058874 -59.201448
# 4  Santa Cruz -48.815485 -69.955762

# %%
pd.read_json('Provincias_Argentinas.json',orient='index')
# Out:
#                                     0                      1   \
# Nombre Completo  Provincia de Misiones  Provincia de San Luis
# Fuente                             IGN                    IGN
# Iso_ID                            AR-N                   AR-D
# Nombre                        Misiones               San Luis
# Id                                  54                     74
# Categoría                    Provincia              Provincia
# Iso_Nombre                    Misiones               San Luis
# Latitud                     -26.875397             -33.757726
# Longitud                    -54.651697             -66.028130
#
#                                     2                        3   \
# Nombre Completo  Provincia de San Juan  Provincia de Entre Ríos
# Fuente                             IGN                      IGN
# Iso_ID                            AR-J                     AR-E
# Nombre                        San Juan               Entre Ríos
# ...

# %% [markdown]
# # APIS

# %%
import requests
import json
import pandas as pd
url='https://raw.githubusercontent.com/bttmly/nba/master/data/teams.json'
df= requests.get(url)
print(df)
# Out:
# <Response [200]>

# %%
import requests
import json
import pandas as pd
url='https://raw.githubusercontent.com/docentemasterd/JSON_JS/master/squad.json'
df1= requests.get(url)
print(df1)
# Out:
# <Response [200]>

# %%
print(len(df1.text))
df1.text
# Out:
# 913
# ...

# %%
texto1=df1.text
json.loads(texto1)
# Out:
# {'squadName': 'Superhero Squad',
#  'homeTown': 'Metro City',
#  'formed': 2016,
#  'secretBase': 'Super Torre',
#  'active': True,
#  'members': [{'name': 'Molecula Man',
#    'age': 29,
#    'secretIdentity': 'Dan Jukes',
#    'powers': ['Resistencia a la radiación',
#     'Reducción corporal',
#     'Rayo incandescente']},
#   {'name': 'Madame Uppercut',
#    'age': 39,
#    'secretIdentity': 'Jane Wilson',
#    'powers': ['Puño del millón de toneladas',
#     'Resistencia al daño',
#     'Reflejos superhumanos']},
#   {'name': 'Llama Eterna',
#    'age': 1000000,
#    'secretIdentity': 'Desconocida',
#    'powers': ['Inmortalidad',
#     'Inmunidad al calor',
#     'Puño del infierno',
#     'Teletransporte',
#     'Viaje interdimensional']}]}

# %%
jsondata1=json.loads(texto1)
df3=pd.DataFrame.from_dict(jsondata1)
df3.head()
# Out:
#          squadName    homeTown  formed   secretBase  active  \
# 0  Superhero Squad  Metro City    2016  Super Torre    True
# 1  Superhero Squad  Metro City    2016  Super Torre    True
# 2  Superhero Squad  Metro City    2016  Super Torre    True
#
#                                              members
# 0  {'name': 'Molecula Man', 'age': 29, 'secretIde...
# 1  {'name': 'Madame Uppercut', 'age': 39, 'secret...
# 2  {'name': 'Llama Eterna', 'age': 1000000, 'secr...

# %%
df3.shape
# Out:
# (3, 6)

# %% [markdown]
# # Google API - Youtube - Claro Leonardo
# # Ejemplo en vivo

# %% [markdown]
# Ir a la siguiente página: https://console.developers.google.com/
# Elegir el botón My First Project

# %% [markdown]
# ![01.png](data:image/png;base64,...)

# %% [markdown]
# Elegir la opcion Proyecto nuevo:
# ![02.png](data:image/png;base64,...)

# %% [markdown]
# Colocar el nombre del proyecto: Youtube-API
#
# Pueden elegir la opcion Organización: Sin organización
# ![03.png](data:image/png;base64,...)

# %% [markdown]
# Luego dar click en Crear
#
# Es bueno recordar que Google tiene multiples API pero en este caso particular estaremos viendo el ejemplo con la API de Youtube
#
# Al momento de crear y seleccionar el proyecto deberan ver un mensaje que dice + habilitar API y Servicios

# %% [markdown]
# ![04.png](data:image/png;base64,...)

# %% [markdown]
# Damos click en ese boton y debera aparecer una ventana como la siguiente:

# %% [markdown]
# ![05.png](data:image/png;base64,...)

# %% [markdown]
# Buscamos la API de Youtube escribiendo Youtube en la barra de navegacion y damos enter:
#
# Apareceran diversas APIS:

# %% [markdown]
# ![06.png](data:image/png;base64,...)

# %% [markdown]
# Para este caso particular vamos a usar la API: Youtube Data API v3 la seleccionamos, luego damos clieck en el botón Habilitar
# ![07.png](data:image/png;base64,...)

# %% [markdown]
# Aparecera una ventana como la siguiente:
# ![08.png](data:image/png;base64,...)

# %% [markdown]
# Ahora que ya tenemos habilitada la API solo debemos crear una API Key
#
# Damos click en el boton Crea Credenciales
# ![08.png](data:image/png;base64,...)

# %% [markdown]
# Deberemos hacer la siguiente seleccion:
#
# ![09.png](data:image/png;base64,...)

# %% [markdown]
# Damos click en Siguiente y debera aparecer la siguiente ventana con la respectiva API key:
# ![11.png](data:image/png;base64,...)

# %% [markdown]
# Copiamos la API key y damos click en Done (Listo) y aparecera la siguiente ventana:
# ![12.png](data:image/png;base64,...)

# %% [markdown]
# Guargemos la API en una variable string

# %%
api_key='AIzaSyDt-LdkSaEDco1goMXZX0xreNKh16MgyaQ' # La borrare despues asi que no se preocupen
api_key_1='AIzaSyDGOcgScVtiiLArGO9G6bNVBfBzdg8GtLg'
# Pueden guardar esta key en un archivo encriptado o en un archivo de configuration para que no se puede extraer de ningun lado

# %% [markdown]
# Para obtener documentacion de la API de google pueden ir a:
# https://github.com/googleapis/google-api-python-client

# %%
# Instalando libreria
# !pip install google-api-python-client
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# Vamos a la seccion docs en la pagina de Github
# Seleccionamos la Opcion Docs> Getting Started
# ![20.png](data:image/png;base64,...)

# %% [markdown]
# ![21.png](data:image/png;base64,...)

# %% [markdown]
# Buscamos la seccion Building and calling a service y seleccionamos el boton Supported API
# ![22.png](data:image/png;base64,...)

# %% [markdown]
# Si buscamos la opcion youtube veremos lo siguiente:
# ![23.png](data:image/png;base64,...)

# %% [markdown]
# Si damos click en v3 podemos observar todos los metodos disponibles
# ![24.png](data:image/png;base64,...)

# %% [markdown]
# Podemos explorar el metodo channels:
# https://googleapis.github.io/google-api-python-client/docs/dyn/youtube_v3.channels.html

# %% [markdown]
# Si quieren encontrar mayor información sobre la google de api pueden ir a está página:
#
# https://developers.google.com/youtube/v3

# %% [markdown]
# Podemos dar clieck en Reference > channels > list para mayor informacion: ![texto del enlace](data:image/png;base64,...))

# %% [markdown]
# Para la opcion Part podemos utilizar las siguientes opciones:
# ![26.png](data:image/png;base64,...)

# %% [markdown]
# En este ejemplo particular usaremos statistics, por si requerimos obtener las estadisticas de algun canal particular

# %%
from googleapiclient.discovery import build
#api_key='AIzaSyDt-LdkSaEDco1goMXZX0xreNKh16MgyaQ' # La borrare despues asi que no se preocupen
api_key_1= 'AIzaSyDGOcgScVtiiLArGO9G6bNVBfBzdg8GtLg' #Api_key de Leonardo

#youtube_david= build('youtube','v3',developerKey=api_key)
youtube_david= build('youtube','v3',developerKey=api_key_1)

# %%
request=youtube_david.channels().list(
    part='statistics',
    forUsername= 'schafer5' # puede reemplazarse por cualquiera
)

# %%
response=request.execute()
print(response) # Obtenemos informacion
# Out:
# {'kind': 'youtube#channelListResponse', 'etag': 'VyRl9dymZp9ohOE-KMzOCL6jI4k', 'pageInfo': {'totalResults': 1, 'resultsPerPage': 5}, 'items': [{'kind': 'youtube#channel', 'etag': 'AmPs9OZ3a438Zl-jm_CKO2mA6gA', 'id': 'UCCezIgC97PvUuR4_gbFUs5g', 'statistics': {'viewCount': '84730989', 'subscriberCount': '1110000', 'hiddenSubscriberCount': False, 'videoCount': '231'}}]}

# %%
type(response)
# Out:
# dict

# %%
response['pageInfo']
# Out:
# {'totalResults': 1, 'resultsPerPage': 5}

# %%
response['items']
# Out:
# [{'kind': 'youtube#channel',
#   'etag': 'AmPs9OZ3a438Zl-jm_CKO2mA6gA',
#   'id': 'UCCezIgC97PvUuR4_gbFUs5g',
#   'statistics': {'viewCount': '84730989',
#    'subscriberCount': '1110000',
#    'hiddenSubscriberCount': False,
#    'videoCount': '231'}}]

# %%
response['kind']
# Out:
# 'youtube#channelListResponse'

# %%
# Miremos en un canal diferente por ejemplo DW
request2=youtube_david.channels().list(
    part='statistics',
    forUsername= 'sentdex' # puede reemplazarse por cualquiera
)
response2=request2.execute()
print(response2) # Obtenemos informacion
print(response2['items'])
print(response2['pageInfo'])
# Out:
# {'kind': 'youtube#channelListResponse', 'etag': 'ASQpXMMjJftf4KHRE5SyXicIx3E', 'pageInfo': {'totalResults': 1, 'resultsPerPage': 5}, 'items': [{'kind': 'youtube#channel', 'etag': 'ngYvzLquTJkkxVh3FGI9xIobe-E', 'id': 'UCfzlCWGWYyIQ0aLC5w48gBQ', 'statistics': {'viewCount': '109235174', 'subscriberCount': '1220000', 'hiddenSubscriberCount': False, 'videoCount': '1239'}}]}
# [{'kind': 'youtube#channel', 'etag': 'ngYvzLquTJkkxVh3FGI9xIobe-E', 'id': 'UCfzlCWGWYyIQ0aLC5w48gBQ', 'statistics': {'viewCount': '109235174', 'subscriberCount': '1220000', 'hiddenSubscriberCount': False, 'videoCount': '1239'}}]
# {'totalResults': 1, 'resultsPerPage': 5}
