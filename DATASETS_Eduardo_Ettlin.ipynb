# %% [markdown]
# <a href="https://colab.research.google.com/github/EWECORP/DScience_41870/blob/main/DATASETS_Eduardo_Ettlin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![CODERHOUSE.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # **CURSO DE DATA SCIENCE**
# # Comisión 41870
#
# # **DESAFIO N° 1 - ELECCION DE DATASETS**
#
# *AUTOR: Eduardo Ettlin

# %%
from google.colab import drive
import os
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# **1er. DATASET:**
# Link de acceso al sitio de Kaggle: https://www.kaggle.com/datasets/sobhanmoosavi/us-accidents
# ![dataset-cover.jpg](data:image/jpeg;base64,...)
#
#
# Contiene la información sobre accidentes en las principales ciudades de EE. UU. Posee una gran cantidad de variables que podrían relacionar causas y efectos de accidentes.

# %%
import pandas as pd

df1 =  pd.read_csv('/content/gdrive/MyDrive/DScience_41870/US_Accidents_Dec21_updated.csv')

# %%
df1.head(7)
# Out:
#     ID  Severity           Start_Time             End_Time  Start_Lat  \
# 0  A-1         3  2016-02-08 00:37:08  2016-02-08 06:37:08  40.108910
# 1  A-2         2  2016-02-08 05:56:20  2016-02-08 11:56:20  39.865420
# 2  A-3         2  2016-02-08 06:15:39  2016-02-08 12:15:39  39.102660
# 3  A-4         2  2016-02-08 06:51:45  2016-02-08 12:51:45  41.062130
# 4  A-5         3  2016-02-08 07:53:43  2016-02-08 13:53:43  39.172393
# 5  A-6         2  2016-02-08 08:16:57  2016-02-08 14:16:57  39.063240
# 6  A-7         2  2016-02-08 08:15:41  2016-02-08 14:15:41  39.775650
#
#    Start_Lng    End_Lat    End_Lng  Distance(mi)  \
# 0 -83.092860  40.112060 -83.031870         3.230
# 1 -84.062800  39.865010 -84.048730         0.747
# 2 -84.524680  39.102090 -84.523960         0.055
# 3 -81.537840  41.062170 -81.535470         0.123
# 4 -84.492792  39.170476 -84.501798         0.500
# 5 -84.032430  39.067310 -84.058510         1.427
# 6 -84.186030  39.772750 -84.188050         0.227
#
# ...

# %%
df1.shape
# Out:
# (2845342, 47)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2845342 entries, 0 to 2845341
# Data columns (total 47 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Severity               int64
#  2   Start_Time             object
#  3   End_Time               object
#  4   Start_Lat              float64
#  5   Start_Lng              float64
#  6   End_Lat                float64
#  7   End_Lng                float64
#  8   Distance(mi)           float64
#  9   Description            object
#  10  Number                 float64
#  11  Street                 object
#  12  Side                   object
#  13  City                   object
#  14  County                 object
#  15  State                  object
#  16  Zipcode                object
#  17  Country                object
#  18  Timezone               object
#  19  Airport_Code           object
#  20  Weather_Timestamp      object
# ...

# %% [markdown]
# # PORTAL DE DATOS ECONÓMICOS
#
# ![datosgobar-logo.svg](data:image/svg+xml;base64,...)
#
# https://www.economia.gob.ar/datos/
#
# Contiene la información de la evolución de los principales datos de deuda externa y su evolución.

# %%
import pandas as pd
df2 =  pd.read_csv('/content/gdrive/MyDrive/DScience_41870/deuda-externa-privada-bcra.csv')

# %%
df2
# Out:
#    indice_tiempo         total  por_categoria_deuda_comercial  \
# 0     2001-10-01  79076.294643                   18170.713135
# 1     2002-01-01           NaN                            NaN
# 2     2002-04-01  72493.881545                   16620.902412
# 3     2002-07-01  70602.910054                   15533.652507
# 4     2002-10-01  67858.556386                   14186.987034
# ..           ...           ...                            ...
# 59    2016-07-01  62732.817240                   34112.404029
# 60    2016-10-01  59368.244919                   31819.303517
# 61    2017-01-01  62463.743845                   32754.813677
# 62    2017-04-01  63852.588296                   33581.057594
# 63    2017-07-01  67941.875252                   34853.332525
#
#     anticipos_prefinanciacion_bienes  deuda_por_importacion_bienes  \
# 0                        5768.970596                  10156.751495
# 1                                NaN                           NaN
# ...

# %% [markdown]
# ---
#
#
#
# ---

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 23 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   indice_tiempo                                               64 non-null     object
#  1   total                                                       63 non-null     float64
#  2   por_categoria_deuda_comercial                               63 non-null     float64
#  3   anticipos_prefinanciacion_bienes                            63 non-null     float64
#  4   deuda_por_importacion_bienes                                63 non-null     float64
#  5   deuda_comercial_servicios                                   63 non-null     float64
#  6   deuda_comercial_lineas_credito                              63 non-null     float64
# ...

# %%
df21 =  pd.read_csv('/content/gdrive/MyDrive/DScience_41870/estimacion-deuda-externa-bruta-por-sector-residente-saldos-fin-periodo-millones-dolares.csv')

# %%
df21
# Out:
#    indice_tiempo  total_deuda_externa  total_deuda_gobierno_general  \
# 0     2006-01-01        130145.321159                  80208.277510
# 1     2006-04-01        133565.591317                  83587.147869
# 2     2006-07-01        133936.591957                  83793.107135
# 3     2006-10-01        137089.893967                  87606.449952
# 4     2007-01-01        139734.393484                  90120.152410
# ..           ...                  ...                           ...
# 62    2021-07-01        268980.763546                 160281.042859
# 63    2021-10-01        267867.517214                 160596.204211
# 64    2022-01-01        275403.822579                 164238.100035
# 65    2022-04-01        275777.394495                 162397.195838
# 66    2022-07-01        271775.576508                 152618.714194
#
#     deuda_gobierno_general_monedas_depositos  \
# 0                                        0.0
# 1                                        0.0
# ...

# %%
df21.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 34 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   indice_tiempo                                               67 non-null     object
#  1   total_deuda_externa                                         67 non-null     float64
#  2   total_deuda_gobierno_general                                67 non-null     float64
#  3   deuda_gobierno_general_monedas_depositos                    67 non-null     float64
#  4   deuda_gobierno_general_titulos_deuda                        67 non-null     float64
#  5   deuda_gobierno_general_prestamos                            67 non-null     float64
#  6   deuda_gobierno_general_creditos_anticipos_comerciales       67 non-null     float64
# ...

# %% [markdown]
# **3er. Dataset:** Link de acceso al sitio de Kaggle:https://www.kaggle.com/datasets/hosseinah1/poker-game-dataset?resource=download
#
# ![Poker_dataset.jpg](data:image/jpeg;base64,...)
#
# Este conjunto de datos de la efectividad y probabilidad de ganar de las distintas manos y combinaciones en el POKER.

# %%
import pandas as pd
df3 =  pd.read_csv('/content/gdrive/MyDrive/DScience_41870/poker-hand-testing.csv')

# %%
df3
# Out:
#         Suit of Card 1  Rank of Card 1  Suit of Card 2  Rank of Card 2  \
# 0                    1               1               1              13
# 1                    3              12               3               2
# 2                    1               9               4               6
# 3                    1               4               3              13
# 4                    3              10               2               7
# ...                ...             ...             ...             ...
# 999995               3               1               1              12
# 999996               3               3               4               5
# 999997               1              11               4               7
# 999998               3              11               1               8
# 999999               2               5               2               9
#
#         Suit of Card 3  Rank of Card 3  Suit of Card 4  Rank of Card 4  \
# ...

# %%
df3.shape
# Out:
# (1000000, 11)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 11 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   Suit of Card 1  1000000 non-null  int64
#  1   Rank of Card 1  1000000 non-null  int64
#  2   Suit of Card 2  1000000 non-null  int64
#  3   Rank of Card 2  1000000 non-null  int64
#  4   Suit of Card 3  1000000 non-null  int64
#  5   Rank of Card 3  1000000 non-null  int64
#  6   Suit of Card 4  1000000 non-null  int64
#  7   Rank of Card 4  1000000 non-null  int64
#  8   Suit of Card 5  1000000 non-null  int64
#  9   Rank of Card 5  1000000 non-null  int64
#  10  Poker Hand      1000000 non-null  int64
# dtypes: int64(11)
# memory usage: 83.9 MB
